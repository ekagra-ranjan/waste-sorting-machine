# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# file = drive.CreateFile({'id': '1aLon9sOQd49HNV0-Deo2XMwf-49XlL5P'})
# file.GetContentFile('data.zip')
# file = drive.CreateFile({'id': '1STxR_DQE0JCDpIE_9JzkgTTx4j-ga7YG'})
# file.GetContentFile('annotations.zip')
file = drive.CreateFile({'id': '1L65sqe976Ty4bl47wn8Wzpk-BmEVLUAR'})
file.GetContentFile('data.zip')

# %%
# !unzip data.zip >/dev/null
# !unzip annotations.zip >/dev/null
# !rm ./Data/56478665_421907071715102_3762114008077828096_n.jpg # this image has no object, so removing it (no xml exists for it)
# !rm ./Data/55912462_267292044150469_7933255829271085056_n.jpg # this image has no object, so removing it (no xml exists for it)

# %%
import cv2
import glob
import xml.etree.ElementTree as ET
import os
import numpy as np
from matplotlib import pyplot as plt
import imutils
from PIL import Image

from tensorflow.keras import Model
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.layers import Conv2D, Reshape, Flatten, Dense, BatchNormalization, Input, Dropout
from tensorflow.keras.utils import Sequence
from tensorflow.keras.backend import epsilon
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

import pandas as pd
import random
from skimage.transform import resize
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
img_shape = 224

# %%
def scale(img, imgNewWidth, imgNewHeight, imgX1=None, imgX2=None, imgY1=None, imgY2=None, interpolation=cv2.INTER_LINEAR):
    
    '''Args: Image, new image width, new image height, 
                 top left point x-coordinates, bottom right point x-coordinates,
                 top left point y-coordinates, bottom right point y-coordinates'''

    imgTemp = img.copy()
    imgHeight, imgWidth, _ = imgTemp.shape
    
    imgTemp = cv2.resize(imgTemp, (imgNewWidth, imgNewHeight), interpolation=interpolation)
    
    if imgX1!=None:
        fY = float(imgNewHeight)/float(imgHeight)
        fX = float(imgNewWidth)/float(imgWidth)

        imgX1 = max(0, int(imgX1*fX))
        imgX2 = min(int(imgX2*fX), imgNewWidth)
        imgY1 = max(0, int(imgY1*fY))
        imgY2 = min(int(imgY2*fY), imgNewHeight)


        return imgTemp, imgX1, imgX2, imgY1, imgY2
    else:
        return imgTemp

# %%
def shuffle_in_unison(a, b):
    assert len(a) == len(b)
    shuffled_a = np.empty(a.shape, dtype=a.dtype)
    shuffled_b = np.empty(b.shape, dtype=b.dtype)
    permutation = np.random.permutation(len(a))
    for old_index, new_index in enumerate(permutation):
        shuffled_a[new_index] = a[old_index]
        shuffled_b[new_index] = b[old_index]
    return shuffled_a, shuffled_b

# %%
def ip(img):
  img = cv2.GaussianBlur(img, (69, 69), 500)
  hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
  # hsv = cv2.threshold(hsv,127,255,cv2.THRESH_BINARY_INV)

  lower = np.array([1,0,0])
  upper = np.array([255,255,100])
  
  mask = cv2.inRange(hsv, lower, upper)
  
  return mask

# %%
nobot_images = []
bot_images = []
nobot_labels = []
bot_labels = [] # labels are [xmin, xmax, ymin, ymax]
file_list = list(glob.glob('./Images/*/*'))
for file in file_list:
  img = cv2.imread(file)
  mask = np.expand_dims(ip(img),axis=2)
  img = np.stack([img[:,:,2], img[:,:,1], img[:,:,0]], axis=2)
#   img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#   tree = ET.parse(os.path.join(annot_dir, file.split('/')[-1])[:-3] + 'xml')
  tree = ET.parse(os.path.join('Labels', '/'.join(file.split('/')[-2:])[:-3] + 'xml'))
  root = tree.getroot()
  size = root.find('size')
  width = int(size.find('width').text)
  height = int(size.find('height').text)
  box = (root.find('object')).find('bndbox')
  xmin = int(box[0].text)
  ymin = int(box[1].text)
  xmax = int(box[2].text)
  ymax = int(box[3].text)
  
#   if(width > height):
#     img = imutils.rotate_bound(img, 90)
#     xmax, ymin, xmin, ymax = height-ymin, xmin, height-ymax, xmax

  img = preprocess_input(img)
  mask = np.expand_dims(scale(mask, img_shape, img_shape), axis=2)
  img, xmin, xmax, ymin, ymax = scale(img, img_shape, img_shape, xmin, xmax, ymin, ymax)
  img = np.concatenate([img, mask], axis=2)
  
  if (file.split('/')[-2] == 'Cropped Bottles'):
    bot_images.append(img)
    bot_labels.append([xmin, xmax, ymin, ymax])
  else:
    nobot_images.append(img)
    nobot_labels.append([xmin, xmax, ymin, ymax])
    
nobot_images = np.array(nobot_images)
bot_images = np.array(bot_images)
nobot_labels = np.array(nobot_labels)
bot_labels = np.array(bot_labels) 

# images = np.stack(3*[images], axis=3)
# images = (images-np.mean(images, axis=0))/(np.max(images)-np.min(images))

# %%
print(nobot_images.shape, nobot_labels.shape, bot_images.shape, bot_images.shape)
# Out:
# (563, 224, 224, 4) (563, 4) (253, 224, 224, 4) (253, 224, 224, 4)

# %%
def horizontalFlip(img, imgX1=None, imgX2=None, imgY1=None, imgY2=None):
    '''Args: Image, top left point x-coordinates, bottom right point x-coordinates,
                 top left point y-coordinates, bottom right point y-coordinates 
                 original_shape = (height, width)'''
    
    imgTemp = img.copy()
    imgHeight, imgWidth, _ = img.shape
    imgTemp = cv2.flip(imgTemp, 1)
    
    if imgX1!=None:
        imgX1, imgX2 = imgWidth - imgX2, imgWidth - imgX1 
        imgY1 = imgY1
        imgY2 = imgY2
        
        return imgTemp, imgX1, imgX2, imgY1, imgY2
    else:
        return imgTemp 

def verticalFlip(img, imgX1=None, imgX2=None, imgY1=None, imgY2=None):
    
    '''Args: Image, top left point x-coordinates, bottom right point x-coordinates,
                 top left point y-coordinates, bottom right point y-coordinates
    '''
    
    imgTemp = img.copy()
    imgHeight, imgWidth, _ = img.shape
    imgTemp = cv2.flip(imgTemp, 0)
    
    if imgX1!=None:
        imgX1 = imgX1
        imgX2 = imgX2 
        imgY1, imgY2 = imgHeight - imgY2, imgHeight - imgY1

        return imgTemp, imgX1, imgX2, imgY1, imgY2
    else:
        return imgTemp

# %%
class DataGenerator(Sequence):

    def __init__(self, images, labels, batch_size, val=False, p=0.5, scale_range=(0.8,1.2)):
      
        super(DataGenerator, self).__init__()
        
        images, labels = shuffle_in_unison(images, labels)
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.index = 0
        self.p = p
        self.scale_range = scale_range
        self.index=0

    def __len__(self):
        return int(len(self.images)/self.batch_size)+1
    
#     def on_epoch_end():
#         self.images, self.labels = shuffle_in_unison(self.images, self.labels)

    def __getitem__(self, idx):
        
        batch_images = []
        batch_coords = []
        for i in range(self.batch_size):
          image = (self.images[((idx*self.batch_size)+i) % len(self.images)]).copy()
          label = (self.labels[((idx*self.batch_size)+i) % len(self.images)]).copy()
          
          if random.random() > self.p:
            image, label[0], label[1], label[2], label[3] = horizontalFlip(image, imgX1=label[0], imgX2=label[1], imgY1=label[2], imgY2=label[3])
          if random.random() > self.p:
            image, label[0], label[1], label[2], label[3] = verticalFlip(image, imgX1=label[0], imgX2=label[1], imgY1=label[2], imgY2=label[3])

          batch_images.append(image)
          batch_coords.append(label)
        
        # batch_images [batch_size, img_shape, img_shape, 3]
        # batch_coords [batch_size, 4] - [x,x+w,y,y+h] - x,y is top left corner
        
        return np.array(batch_images), np.array(batch_coords)

# %%
val_split = 0.1

# %%
bot_images, bot_labels = shuffle_in_unison(bot_images, bot_labels)
nobot_images, nobot_labels = shuffle_in_unison(nobot_images, nobot_labels)

bot_train_examples = int(bot_images.shape[0] * (1-val_split))
nobot_train_examples = int(nobot_images.shape[0] * (1-val_split))

train_images = np.concatenate([bot_images[:bot_train_examples], nobot_images[:nobot_train_examples]], axis=0)
val_images = np.concatenate([bot_images[bot_train_examples:], nobot_images[nobot_train_examples:]], axis=0)

train_labels = np.concatenate([bot_labels[:bot_train_examples], nobot_labels[:nobot_train_examples]], axis=0)
val_labels = np.concatenate([bot_labels[bot_train_examples:], nobot_labels[nobot_train_examples:]], axis=0)

# train_labels_cat = to_categorical(train_labels[:,-1], num_classes=2, dtype='uint8')
# val_labels_cat = to_categorical(val_labels[:,-1], num_classes=2, dtype='uint8')

# train_labels_cat = train_labels[:,-1]
# val_labels_cat = val_labels[:,-1]

# train_labels = train_labels[:,:-1]
# val_labels = val_labels[:,:-1]

print(bot_train_examples, ' training examples of bottle')
print(bot_images.shape[0] - bot_train_examples, ' validation examples of bottle')

print(nobot_train_examples, ' training examples of non-bottle')
print(nobot_images.shape[0] - nobot_train_examples, ' validation examples of non-bottle')

print('total ', train_images.shape[0], ' training images')
print('total ', val_images.shape[0], ' val images')

train_datagen = DataGenerator(train_images, train_labels, 4)
val_datagen = DataGenerator(val_images, val_labels, 4)
# Out:
# 227  training examples of bottle
# 26  validation examples of bottle
# 506  training examples of non-bottle
# 57  validation examples of non-bottle
# total  733  training images
# total  83  val images

# %%
# model = MobileNetV2(input_shape=(224, 224, 3), include_top=False)
# model.summary()

# %%
def create_model(img_size=224, trainable=False):

#     model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False)
    
#     for layer in model.layers:
#         layer.trainable = trainable
        
#     for layer in model.layers:
#       if layer.name == 'block_3_project_BN':
#         x = layer.output
#         break
    
    regulariz = regularizers.l2(1)
#     regulariz = None
        
    inp = Input(shape=(224, 224, 4))
    x = Conv2D(28, kernel_size=3, name="new_conv", activation='relu', kernel_regularizer=regulariz)(inp)
    x = BatchNormalization()(x)
    x = Conv2D(48, kernel_size=3, name="new_conv1", activation='relu', kernel_regularizer=regulariz)(x)
#     x = BatchNormalization()(x)
    x = Conv2D(56, kernel_size=3, name="new_conv3", activation='relu')(x)
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    x = Dense(32, activation='relu', kernel_regularizer=regulariz)(x)
    pred = Dense(4, name="pred")(x)

    return Model(inputs=inp, outputs=pred)

# %%
model = create_model(img_size=img_shape)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 4)       0
# _________________________________________________________________
# new_conv (Conv2D)            (None, 222, 222, 28)      1036
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 222, 222, 28)      112
# _________________________________________________________________
# new_conv1 (Conv2D)           (None, 220, 220, 48)      12144
# _________________________________________________________________
# new_conv3 (Conv2D)           (None, 218, 218, 56)      24248
# _________________________________________________________________
# flatten (Flatten)            (None, 2661344)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 2661344)           0
# _________________________________________________________________
# dense (Dense)                (None, 32)                85163040
# _________________________________________________________________
# pred (Dense)                 (None, 4)                 132
# =================================================================
# Total params: 85,200,712
# Trainable params: 85,200,656
# Non-trainable params: 56
# _________________________________________________________________

# %%
def iou_metric(y_true, y_pred):
  
    '''label format - [xmin, xmax, ymin, ymax]'''
    
#     print(y_pred.shape)
    
    gt = y_true
    pred = y_pred

    diff_width = K.minimum(gt[:,1], pred[:,1]) - K.maximum(gt[:,0], pred[:,0])
    diff_height = K.minimum(gt[:,3], pred[:,3]) - K.maximum(gt[:,2], pred[:,2])
    intersection = K.maximum(diff_width, 0) * K.maximum(diff_height, 0)

    area_gt = (gt[:,1]-gt[:,0]) * (gt[:,3]-gt[:,2])
    area_pred = (pred[:,1]-pred[:,0]) * (pred[:,3]-pred[:,2])
    union = K.maximum(area_gt + area_pred - intersection, 0)
    
    iou = K.round(intersection / (union + epsilon()))
    
    return iou

# %%
lr = 1e-4
epochs=500

# %%
# loss_weights = {"pred" : 1, "class_" : 100}

model.compile(loss="mean_squared_error", optimizer= optimizers.Adam(lr=lr), metrics=[iou_metric])

# print(model.metrics_name)

checkpoint = ModelCheckpoint("model-{val_iou_metric:.2f}.h5", monitor="val_iou_metric", verbose=1, save_best_only=True,
                             save_weights_only=True, mode="max", period=5)
# stop = EarlyStopping(monitor="iou_metric", patience=5, mode="max")
# reduce_lr = ReduceLROnPlateau(monitor="iou_metric", factor=0.2, patience=10, min_lr=1e-7, verbose=1, mode="max")

model.fit_generator(generator=train_datagen, validation_data=val_datagen, epochs=epochs, callbacks=[checkpoint], shuffle=True, verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 21/21 [==============================] - 0s 21ms/step - loss: 630.6521 - iou_metric: 0.1310
# 184/184 [==============================] - 21s 117ms/step - loss: 1202.4140 - iou_metric: 0.1562 - val_loss: 630.6521 - val_iou_metric: 0.1310
# Epoch 2/500
# 21/21 [==============================] - 0s 16ms/step - loss: 536.8448 - iou_metric: 0.2738
# 184/184 [==============================] - 18s 98ms/step - loss: 574.2126 - iou_metric: 0.3315 - val_loss: 536.8448 - val_iou_metric: 0.2738
# Epoch 3/500
# 21/21 [==============================] - 0s 15ms/step - loss: 485.5816 - iou_metric: 0.3810
# 184/184 [==============================] - 18s 98ms/step - loss: 474.2299 - iou_metric: 0.4171 - val_loss: 485.5816 - val_iou_metric: 0.3810
# Epoch 4/500
# 21/21 [==============================] - 0s 16ms/step - loss: 488.9841 - iou_metric: 0.4048
# 184/184 [==============================] - 18s 97ms/step - loss: 403.4482 - iou_metric: 0.4946 - val_loss: 488.9841 - val_iou_metric: 0.4048
# Epoch 5/500
# 21/21 [==============================] - 0s 16ms/step - loss: 408.1707 - iou_metric: 0.5119
#
# Epoch 00005: val_iou_metric improved from -inf to 0.51190, saving model to model-0.51.h5
# 184/184 [==============================] - 19s 104ms/step - loss: 400.4990 - iou_metric: 0.5136 - val_loss: 408.1707 - val_iou_metric: 0.5119
# Epoch 6/500
# 21/21 [==============================] - 0s 16ms/step - loss: 425.9751 - iou_metric: 0.4524
# 184/184 [==============================] - 18s 98ms/step - loss: 361.3276 - iou_metric: 0.5394 - val_loss: 425.9751 - val_iou_metric: 0.4524
# Epoch 7/500
# 21/21 [==============================] - 0s 15ms/step - loss: 412.0693 - iou_metric: 0.5000
# 184/184 [==============================] - 18s 98ms/step - loss: 337.1600 - iou_metric: 0.6046 - val_loss: 412.0693 - val_iou_metric: 0.5000
# Epoch 8/500
# 21/21 [==============================] - 0s 16ms/step - loss: 410.3747 - iou_metric: 0.5476
# 184/184 [==============================] - 18s 98ms/step - loss: 311.7472 - iou_metric: 0.6630 - val_loss: 410.3747 - val_iou_metric: 0.5476
# Epoch 9/500
# 21/21 [==============================] - 0s 16ms/step - loss: 382.3500 - iou_metric: 0.5952
# 184/184 [==============================] - 18s 98ms/step - loss: 308.1740 - iou_metric: 0.6481 - val_loss: 382.3500 - val_iou_metric: 0.5952
# Epoch 10/500
# 21/21 [==============================] - 0s 16ms/step - loss: 384.2596 - iou_metric: 0.5119
#
# Epoch 00010: val_iou_metric did not improve from 0.51190
# 184/184 [==============================] - 18s 98ms/step - loss: 282.0572 - iou_metric: 0.7092 - val_loss: 384.2596 - val_iou_metric: 0.5119
# Epoch 11/500
# 21/21 [==============================] - 0s 17ms/step - loss: 369.4497 - iou_metric: 0.5119
# 184/184 [==============================] - 18s 98ms/step - loss: 270.2137 - iou_metric: 0.7473 - val_loss: 369.4497 - val_iou_metric: 0.5119
# Epoch 12/500
# 21/21 [==============================] - 0s 16ms/step - loss: 336.9279 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 98ms/step - loss: 257.1688 - iou_metric: 0.7500 - val_loss: 336.9279 - val_iou_metric: 0.6905
# Epoch 13/500
# 21/21 [==============================] - 0s 15ms/step - loss: 391.9982 - iou_metric: 0.5476
# 184/184 [==============================] - 18s 97ms/step - loss: 257.2923 - iou_metric: 0.7649 - val_loss: 391.9982 - val_iou_metric: 0.5476
# Epoch 14/500
# 21/21 [==============================] - 0s 15ms/step - loss: 373.1077 - iou_metric: 0.5714
# 184/184 [==============================] - 18s 98ms/step - loss: 274.4292 - iou_metric: 0.7255 - val_loss: 373.1077 - val_iou_metric: 0.5714
# Epoch 15/500
# 21/21 [==============================] - 0s 16ms/step - loss: 362.9802 - iou_metric: 0.5714
#
# Epoch 00015: val_iou_metric improved from 0.51190 to 0.57143, saving model to model-0.57.h5
# 184/184 [==============================] - 19s 103ms/step - loss: 256.3395 - iou_metric: 0.7894 - val_loss: 362.9802 - val_iou_metric: 0.5714
# Epoch 16/500
# 21/21 [==============================] - 0s 16ms/step - loss: 410.8631 - iou_metric: 0.5714
# 184/184 [==============================] - 18s 98ms/step - loss: 271.0177 - iou_metric: 0.7500 - val_loss: 410.8631 - val_iou_metric: 0.5714
# Epoch 17/500
# 21/21 [==============================] - 0s 16ms/step - loss: 368.6236 - iou_metric: 0.5952
# 184/184 [==============================] - 18s 98ms/step - loss: 253.0450 - iou_metric: 0.7717 - val_loss: 368.6236 - val_iou_metric: 0.5952
# Epoch 18/500
# 21/21 [==============================] - 0s 16ms/step - loss: 413.3967 - iou_metric: 0.5476
# 184/184 [==============================] - 18s 98ms/step - loss: 246.8861 - iou_metric: 0.7853 - val_loss: 413.3967 - val_iou_metric: 0.5476
# Epoch 19/500
# 21/21 [==============================] - 0s 16ms/step - loss: 349.7076 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 245.7274 - iou_metric: 0.7962 - val_loss: 349.7076 - val_iou_metric: 0.6905
# Epoch 20/500
# 21/21 [==============================] - 0s 16ms/step - loss: 383.8916 - iou_metric: 0.6071
#
# Epoch 00020: val_iou_metric improved from 0.57143 to 0.60714, saving model to model-0.61.h5
# 184/184 [==============================] - 19s 104ms/step - loss: 233.8750 - iou_metric: 0.8329 - val_loss: 383.8916 - val_iou_metric: 0.6071
# Epoch 21/500
# 21/21 [==============================] - 0s 16ms/step - loss: 374.5945 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 98ms/step - loss: 257.3423 - iou_metric: 0.7622 - val_loss: 374.5945 - val_iou_metric: 0.6310
# Epoch 22/500
# 21/21 [==============================] - 0s 16ms/step - loss: 375.6358 - iou_metric: 0.5833
# 184/184 [==============================] - 18s 97ms/step - loss: 245.6759 - iou_metric: 0.7962 - val_loss: 375.6358 - val_iou_metric: 0.5833
# Epoch 23/500
# 21/21 [==============================] - 0s 16ms/step - loss: 367.8685 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 97ms/step - loss: 241.1040 - iou_metric: 0.8302 - val_loss: 367.8685 - val_iou_metric: 0.6310
# Epoch 24/500
# 21/21 [==============================] - 0s 16ms/step - loss: 354.9810 - iou_metric: 0.5595
# 184/184 [==============================] - 18s 98ms/step - loss: 253.2120 - iou_metric: 0.8207 - val_loss: 354.9810 - val_iou_metric: 0.5595
# Epoch 25/500
# 21/21 [==============================] - 0s 16ms/step - loss: 386.7709 - iou_metric: 0.6667
#
# Epoch 00025: val_iou_metric improved from 0.60714 to 0.66667, saving model to model-0.67.h5
# 184/184 [==============================] - 19s 103ms/step - loss: 255.8568 - iou_metric: 0.7663 - val_loss: 386.7709 - val_iou_metric: 0.6667
# Epoch 26/500
# 21/21 [==============================] - 0s 16ms/step - loss: 341.2418 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 241.6515 - iou_metric: 0.8438 - val_loss: 341.2418 - val_iou_metric: 0.6667
# Epoch 27/500
# 21/21 [==============================] - 0s 16ms/step - loss: 344.0045 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 244.2063 - iou_metric: 0.8125 - val_loss: 344.0045 - val_iou_metric: 0.7143
# Epoch 28/500
# 21/21 [==============================] - 0s 16ms/step - loss: 367.2235 - iou_metric: 0.6190
# 184/184 [==============================] - 18s 98ms/step - loss: 232.7317 - iou_metric: 0.8492 - val_loss: 367.2235 - val_iou_metric: 0.6190
# Epoch 29/500
# 21/21 [==============================] - 0s 16ms/step - loss: 344.4468 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 225.4696 - iou_metric: 0.8533 - val_loss: 344.4468 - val_iou_metric: 0.6667
# Epoch 30/500
# 21/21 [==============================] - 0s 15ms/step - loss: 380.4291 - iou_metric: 0.6071
#
# Epoch 00030: val_iou_metric did not improve from 0.66667
# 184/184 [==============================] - 18s 97ms/step - loss: 228.4653 - iou_metric: 0.8315 - val_loss: 380.4291 - val_iou_metric: 0.6071
# Epoch 31/500
# 21/21 [==============================] - 0s 16ms/step - loss: 335.0058 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 224.0023 - iou_metric: 0.8451 - val_loss: 335.0058 - val_iou_metric: 0.6667
# Epoch 32/500
# 21/21 [==============================] - 0s 16ms/step - loss: 347.1363 - iou_metric: 0.5952
# 184/184 [==============================] - 18s 97ms/step - loss: 222.6344 - iou_metric: 0.8410 - val_loss: 347.1363 - val_iou_metric: 0.5952
# Epoch 33/500
# 21/21 [==============================] - 0s 16ms/step - loss: 372.0711 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 98ms/step - loss: 217.8071 - iou_metric: 0.8546 - val_loss: 372.0711 - val_iou_metric: 0.6429
# Epoch 34/500
# 21/21 [==============================] - 0s 16ms/step - loss: 356.3841 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 98ms/step - loss: 229.1678 - iou_metric: 0.8492 - val_loss: 356.3841 - val_iou_metric: 0.6429
# Epoch 35/500
# 21/21 [==============================] - 0s 16ms/step - loss: 338.0350 - iou_metric: 0.6429
#
# Epoch 00035: val_iou_metric did not improve from 0.66667
# 184/184 [==============================] - 18s 98ms/step - loss: 222.6370 - iou_metric: 0.8410 - val_loss: 338.0350 - val_iou_metric: 0.6429
# Epoch 36/500
# 21/21 [==============================] - 0s 15ms/step - loss: 330.5997 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 217.9564 - iou_metric: 0.8342 - val_loss: 330.5997 - val_iou_metric: 0.6905
# Epoch 37/500
# 21/21 [==============================] - 0s 15ms/step - loss: 338.7701 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 97ms/step - loss: 225.7835 - iou_metric: 0.8438 - val_loss: 338.7701 - val_iou_metric: 0.6667
# Epoch 38/500
# 21/21 [==============================] - 0s 16ms/step - loss: 328.7103 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 225.5371 - iou_metric: 0.8492 - val_loss: 328.7103 - val_iou_metric: 0.6667
# Epoch 39/500
# 21/21 [==============================] - 0s 15ms/step - loss: 347.8804 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 98ms/step - loss: 218.2969 - iou_metric: 0.8655 - val_loss: 347.8804 - val_iou_metric: 0.6310
# Epoch 40/500
# 21/21 [==============================] - 0s 16ms/step - loss: 329.4359 - iou_metric: 0.6786
#
# Epoch 00040: val_iou_metric improved from 0.66667 to 0.67857, saving model to model-0.68.h5
# 184/184 [==============================] - 19s 104ms/step - loss: 214.8813 - iou_metric: 0.8709 - val_loss: 329.4359 - val_iou_metric: 0.6786
# Epoch 41/500
# 21/21 [==============================] - 0s 15ms/step - loss: 329.4634 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 98ms/step - loss: 212.2411 - iou_metric: 0.8818 - val_loss: 329.4634 - val_iou_metric: 0.6429
# Epoch 42/500
# 21/21 [==============================] - 0s 16ms/step - loss: 339.1300 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 99ms/step - loss: 215.5813 - iou_metric: 0.8478 - val_loss: 339.1300 - val_iou_metric: 0.6667
# Epoch 43/500
# 21/21 [==============================] - 0s 16ms/step - loss: 323.6730 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 98ms/step - loss: 208.0865 - iou_metric: 0.8899 - val_loss: 323.6730 - val_iou_metric: 0.6548
# Epoch 44/500
# 21/21 [==============================] - 0s 16ms/step - loss: 325.7457 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 214.9714 - iou_metric: 0.8519 - val_loss: 325.7457 - val_iou_metric: 0.6667
# Epoch 45/500
# 21/21 [==============================] - 0s 15ms/step - loss: 349.8862 - iou_metric: 0.6310
#
# Epoch 00045: val_iou_metric did not improve from 0.67857
# 184/184 [==============================] - 18s 98ms/step - loss: 209.4464 - iou_metric: 0.8668 - val_loss: 349.8862 - val_iou_metric: 0.6310
# Epoch 46/500
# 21/21 [==============================] - 0s 16ms/step - loss: 324.5310 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 98ms/step - loss: 215.1114 - iou_metric: 0.8478 - val_loss: 324.5310 - val_iou_metric: 0.6786
# Epoch 47/500
# 21/21 [==============================] - 0s 16ms/step - loss: 310.9975 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 199.2464 - iou_metric: 0.8696 - val_loss: 310.9975 - val_iou_metric: 0.6667
# Epoch 48/500
# 21/21 [==============================] - 0s 16ms/step - loss: 378.9993 - iou_metric: 0.5000
# 184/184 [==============================] - 18s 98ms/step - loss: 200.7457 - iou_metric: 0.8723 - val_loss: 378.9993 - val_iou_metric: 0.5000
# Epoch 49/500
# 21/21 [==============================] - 0s 16ms/step - loss: 322.0362 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 199.0107 - iou_metric: 0.8668 - val_loss: 322.0362 - val_iou_metric: 0.7262
# Epoch 50/500
# 21/21 [==============================] - 0s 15ms/step - loss: 306.5888 - iou_metric: 0.6548
#
# Epoch 00050: val_iou_metric did not improve from 0.67857
# 184/184 [==============================] - 18s 98ms/step - loss: 199.6648 - iou_metric: 0.8533 - val_loss: 306.5888 - val_iou_metric: 0.6548
# Epoch 51/500
# 21/21 [==============================] - 0s 16ms/step - loss: 306.1401 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 98ms/step - loss: 199.8517 - iou_metric: 0.8655 - val_loss: 306.1401 - val_iou_metric: 0.6429
# Epoch 52/500
# 21/21 [==============================] - 0s 16ms/step - loss: 328.4075 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 98ms/step - loss: 202.9551 - iou_metric: 0.8492 - val_loss: 328.4075 - val_iou_metric: 0.6548
# Epoch 53/500
# 21/21 [==============================] - 0s 16ms/step - loss: 339.0862 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 196.9654 - iou_metric: 0.8655 - val_loss: 339.0862 - val_iou_metric: 0.7024
# Epoch 54/500
# 21/21 [==============================] - 0s 15ms/step - loss: 307.4298 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 97ms/step - loss: 198.7267 - iou_metric: 0.8628 - val_loss: 307.4298 - val_iou_metric: 0.6786
# Epoch 55/500
# 21/21 [==============================] - 0s 16ms/step - loss: 282.7502 - iou_metric: 0.7024
#
# Epoch 00055: val_iou_metric improved from 0.67857 to 0.70238, saving model to model-0.70.h5
# 184/184 [==============================] - 19s 104ms/step - loss: 187.6305 - iou_metric: 0.8954 - val_loss: 282.7502 - val_iou_metric: 0.7024
# Epoch 56/500
# 21/21 [==============================] - 0s 16ms/step - loss: 295.8342 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 98ms/step - loss: 182.7160 - iou_metric: 0.8899 - val_loss: 295.8342 - val_iou_metric: 0.6786
# Epoch 57/500
# 21/21 [==============================] - 0s 15ms/step - loss: 302.7480 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 97ms/step - loss: 181.4421 - iou_metric: 0.8913 - val_loss: 302.7480 - val_iou_metric: 0.6667
# Epoch 58/500
# 21/21 [==============================] - 0s 15ms/step - loss: 312.8239 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 196.3694 - iou_metric: 0.8519 - val_loss: 312.8239 - val_iou_metric: 0.6905
# Epoch 59/500
# 21/21 [==============================] - 0s 16ms/step - loss: 300.5121 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 97ms/step - loss: 188.2072 - iou_metric: 0.8628 - val_loss: 300.5121 - val_iou_metric: 0.6786
# Epoch 60/500
# 21/21 [==============================] - 0s 16ms/step - loss: 296.2187 - iou_metric: 0.6429
#
# Epoch 00060: val_iou_metric did not improve from 0.70238
# 184/184 [==============================] - 18s 98ms/step - loss: 177.0948 - iou_metric: 0.8967 - val_loss: 296.2187 - val_iou_metric: 0.6429
# Epoch 61/500
# 21/21 [==============================] - 0s 15ms/step - loss: 317.5183 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 97ms/step - loss: 175.4231 - iou_metric: 0.8886 - val_loss: 317.5183 - val_iou_metric: 0.6310
# Epoch 62/500
# 21/21 [==============================] - 0s 16ms/step - loss: 292.9133 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 177.8344 - iou_metric: 0.8899 - val_loss: 292.9133 - val_iou_metric: 0.6905
# Epoch 63/500
# 21/21 [==============================] - 0s 16ms/step - loss: 286.6988 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 98ms/step - loss: 179.6289 - iou_metric: 0.8804 - val_loss: 286.6988 - val_iou_metric: 0.7024
# Epoch 64/500
# 21/21 [==============================] - 0s 16ms/step - loss: 261.4962 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 98ms/step - loss: 179.0922 - iou_metric: 0.8859 - val_loss: 261.4962 - val_iou_metric: 0.6786
# Epoch 65/500
# 21/21 [==============================] - 0s 15ms/step - loss: 309.9017 - iou_metric: 0.6905
#
# Epoch 00065: val_iou_metric did not improve from 0.70238
# 184/184 [==============================] - 18s 98ms/step - loss: 174.1793 - iou_metric: 0.8927 - val_loss: 309.9017 - val_iou_metric: 0.6905
# Epoch 66/500
# 21/21 [==============================] - 0s 16ms/step - loss: 286.1937 - iou_metric: 0.7381
# 184/184 [==============================] - 18s 97ms/step - loss: 170.1547 - iou_metric: 0.8940 - val_loss: 286.1937 - val_iou_metric: 0.7381
# Epoch 67/500
# 21/21 [==============================] - 0s 16ms/step - loss: 314.4673 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 97ms/step - loss: 175.4839 - iou_metric: 0.8791 - val_loss: 314.4673 - val_iou_metric: 0.6429
# Epoch 68/500
# 21/21 [==============================] - 0s 15ms/step - loss: 287.7576 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 98ms/step - loss: 176.0547 - iou_metric: 0.8764 - val_loss: 287.7576 - val_iou_metric: 0.6310
# Epoch 69/500
# 21/21 [==============================] - 0s 16ms/step - loss: 266.8719 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 98ms/step - loss: 173.1425 - iou_metric: 0.8764 - val_loss: 266.8719 - val_iou_metric: 0.7024
# Epoch 70/500
# 21/21 [==============================] - 0s 16ms/step - loss: 284.7494 - iou_metric: 0.6548
#
# Epoch 00070: val_iou_metric did not improve from 0.70238
# 184/184 [==============================] - 18s 97ms/step - loss: 172.7981 - iou_metric: 0.8927 - val_loss: 284.7494 - val_iou_metric: 0.6548
# Epoch 71/500
# 21/21 [==============================] - 0s 15ms/step - loss: 264.8943 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 166.1978 - iou_metric: 0.9090 - val_loss: 264.8943 - val_iou_metric: 0.7262
# Epoch 72/500
# 21/21 [==============================] - 0s 16ms/step - loss: 291.5144 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 162.6294 - iou_metric: 0.9035 - val_loss: 291.5144 - val_iou_metric: 0.6548
# Epoch 73/500
# 21/21 [==============================] - 0s 15ms/step - loss: 280.9231 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 173.2271 - iou_metric: 0.8832 - val_loss: 280.9231 - val_iou_metric: 0.6548
# Epoch 74/500
# 21/21 [==============================] - 0s 16ms/step - loss: 269.0724 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 98ms/step - loss: 166.2371 - iou_metric: 0.8927 - val_loss: 269.0724 - val_iou_metric: 0.7619
# Epoch 75/500
# 21/21 [==============================] - 0s 16ms/step - loss: 255.4174 - iou_metric: 0.6905
#
# Epoch 00075: val_iou_metric did not improve from 0.70238
# 184/184 [==============================] - 18s 97ms/step - loss: 163.4461 - iou_metric: 0.8967 - val_loss: 255.4174 - val_iou_metric: 0.6905
# Epoch 76/500
# 21/21 [==============================] - 0s 15ms/step - loss: 283.4769 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 98ms/step - loss: 162.1637 - iou_metric: 0.8913 - val_loss: 283.4769 - val_iou_metric: 0.6786
# Epoch 77/500
# 21/21 [==============================] - 0s 15ms/step - loss: 295.4173 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 156.8559 - iou_metric: 0.9239 - val_loss: 295.4173 - val_iou_metric: 0.6548
# Epoch 78/500
# 21/21 [==============================] - 0s 15ms/step - loss: 267.3608 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 163.2730 - iou_metric: 0.8940 - val_loss: 267.3608 - val_iou_metric: 0.7262
# Epoch 79/500
# 21/21 [==============================] - 0s 15ms/step - loss: 279.3414 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 97ms/step - loss: 154.4168 - iou_metric: 0.9239 - val_loss: 279.3414 - val_iou_metric: 0.6429
# Epoch 80/500
# 21/21 [==============================] - 0s 15ms/step - loss: 265.8888 - iou_metric: 0.7262
#
# Epoch 00080: val_iou_metric improved from 0.70238 to 0.72619, saving model to model-0.73.h5
# 184/184 [==============================] - 19s 103ms/step - loss: 156.2335 - iou_metric: 0.9008 - val_loss: 265.8888 - val_iou_metric: 0.7262
# Epoch 81/500
# 21/21 [==============================] - 0s 16ms/step - loss: 258.4805 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 98ms/step - loss: 159.5888 - iou_metric: 0.8899 - val_loss: 258.4805 - val_iou_metric: 0.7500
# Epoch 82/500
# 21/21 [==============================] - 0s 16ms/step - loss: 271.0049 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 98ms/step - loss: 157.5646 - iou_metric: 0.9035 - val_loss: 271.0049 - val_iou_metric: 0.6905
# Epoch 83/500
# 21/21 [==============================] - 0s 16ms/step - loss: 239.9964 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 156.9397 - iou_metric: 0.8954 - val_loss: 239.9964 - val_iou_metric: 0.7262
# Epoch 84/500
# 21/21 [==============================] - 0s 15ms/step - loss: 263.1914 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 154.1316 - iou_metric: 0.9022 - val_loss: 263.1914 - val_iou_metric: 0.6548
# Epoch 85/500
# 21/21 [==============================] - 0s 15ms/step - loss: 259.2519 - iou_metric: 0.7262
#
# Epoch 00085: val_iou_metric did not improve from 0.72619
# 184/184 [==============================] - 18s 97ms/step - loss: 157.2076 - iou_metric: 0.8832 - val_loss: 259.2519 - val_iou_metric: 0.7262
# Epoch 86/500
# 21/21 [==============================] - 0s 15ms/step - loss: 272.0648 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 155.9152 - iou_metric: 0.8872 - val_loss: 272.0648 - val_iou_metric: 0.6905
# Epoch 87/500
# 21/21 [==============================] - 0s 16ms/step - loss: 266.2289 - iou_metric: 0.7381
# 184/184 [==============================] - 18s 98ms/step - loss: 151.4369 - iou_metric: 0.8954 - val_loss: 266.2289 - val_iou_metric: 0.7381
# Epoch 88/500
# 21/21 [==============================] - 0s 16ms/step - loss: 266.8866 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 155.1020 - iou_metric: 0.9022 - val_loss: 266.8866 - val_iou_metric: 0.7143
# Epoch 89/500
# 21/21 [==============================] - 0s 16ms/step - loss: 249.4867 - iou_metric: 0.6429
# 184/184 [==============================] - 18s 97ms/step - loss: 148.5394 - iou_metric: 0.9022 - val_loss: 249.4867 - val_iou_metric: 0.6429
# Epoch 90/500
# 21/21 [==============================] - 0s 15ms/step - loss: 230.6726 - iou_metric: 0.6905
#
# Epoch 00090: val_iou_metric did not improve from 0.72619
# 184/184 [==============================] - 18s 97ms/step - loss: 145.3897 - iou_metric: 0.9171 - val_loss: 230.6726 - val_iou_metric: 0.6905
# Epoch 91/500
# 21/21 [==============================] - 0s 17ms/step - loss: 254.1630 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 143.8262 - iou_metric: 0.9130 - val_loss: 254.1630 - val_iou_metric: 0.7024
# Epoch 92/500
# 21/21 [==============================] - 0s 15ms/step - loss: 249.8203 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 146.0030 - iou_metric: 0.9090 - val_loss: 249.8203 - val_iou_metric: 0.7143
# Epoch 93/500
# 21/21 [==============================] - 0s 16ms/step - loss: 250.3413 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 147.8278 - iou_metric: 0.9022 - val_loss: 250.3413 - val_iou_metric: 0.7619
# Epoch 94/500
# 21/21 [==============================] - 0s 16ms/step - loss: 246.2955 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 98ms/step - loss: 146.4779 - iou_metric: 0.8954 - val_loss: 246.2955 - val_iou_metric: 0.6310
# Epoch 95/500
# 21/21 [==============================] - 0s 16ms/step - loss: 244.1515 - iou_metric: 0.7500
#
# Epoch 00095: val_iou_metric improved from 0.72619 to 0.75000, saving model to model-0.75.h5
# 184/184 [==============================] - 19s 103ms/step - loss: 151.2353 - iou_metric: 0.9076 - val_loss: 244.1515 - val_iou_metric: 0.7500
# Epoch 96/500
# 21/21 [==============================] - 0s 16ms/step - loss: 303.2642 - iou_metric: 0.5833
# 184/184 [==============================] - 18s 98ms/step - loss: 150.1284 - iou_metric: 0.8913 - val_loss: 303.2642 - val_iou_metric: 0.5833
# Epoch 97/500
# 21/21 [==============================] - 0s 15ms/step - loss: 237.8174 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 98ms/step - loss: 142.1116 - iou_metric: 0.9062 - val_loss: 237.8174 - val_iou_metric: 0.7500
# Epoch 98/500
# 21/21 [==============================] - 0s 15ms/step - loss: 252.1662 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 98ms/step - loss: 145.9150 - iou_metric: 0.9062 - val_loss: 252.1662 - val_iou_metric: 0.7024
# Epoch 99/500
# 21/21 [==============================] - 0s 16ms/step - loss: 247.9267 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 97ms/step - loss: 142.5229 - iou_metric: 0.8940 - val_loss: 247.9267 - val_iou_metric: 0.7143
# Epoch 100/500
# 21/21 [==============================] - 0s 16ms/step - loss: 240.4503 - iou_metric: 0.7262
#
# Epoch 00100: val_iou_metric did not improve from 0.75000
# 184/184 [==============================] - 18s 98ms/step - loss: 137.7262 - iou_metric: 0.9103 - val_loss: 240.4503 - val_iou_metric: 0.7262
# Epoch 101/500
# 21/21 [==============================] - 0s 15ms/step - loss: 256.9415 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 97ms/step - loss: 139.8031 - iou_metric: 0.9076 - val_loss: 256.9415 - val_iou_metric: 0.6667
# Epoch 102/500
# 21/21 [==============================] - 0s 16ms/step - loss: 241.9621 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 135.0552 - iou_metric: 0.9185 - val_loss: 241.9621 - val_iou_metric: 0.7024
# Epoch 103/500
# 21/21 [==============================] - 0s 15ms/step - loss: 244.4247 - iou_metric: 0.7738
# 184/184 [==============================] - 18s 97ms/step - loss: 138.7140 - iou_metric: 0.9035 - val_loss: 244.4247 - val_iou_metric: 0.7738
# Epoch 104/500
# 21/21 [==============================] - 0s 16ms/step - loss: 223.0623 - iou_metric: 0.7857
# 184/184 [==============================] - 18s 97ms/step - loss: 133.9370 - iou_metric: 0.9239 - val_loss: 223.0623 - val_iou_metric: 0.7857
# Epoch 105/500
# 21/21 [==============================] - 0s 15ms/step - loss: 252.6231 - iou_metric: 0.6905
#
# Epoch 00105: val_iou_metric did not improve from 0.75000
# 184/184 [==============================] - 18s 98ms/step - loss: 135.5093 - iou_metric: 0.9266 - val_loss: 252.6231 - val_iou_metric: 0.6905
# Epoch 106/500
# 21/21 [==============================] - 0s 16ms/step - loss: 229.0045 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 134.4740 - iou_metric: 0.9158 - val_loss: 229.0045 - val_iou_metric: 0.7024
# Epoch 107/500
# 21/21 [==============================] - 0s 16ms/step - loss: 263.6844 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 97ms/step - loss: 134.3476 - iou_metric: 0.9062 - val_loss: 263.6844 - val_iou_metric: 0.6786
# Epoch 108/500
# 21/21 [==============================] - 0s 16ms/step - loss: 232.8813 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 131.6852 - iou_metric: 0.9171 - val_loss: 232.8813 - val_iou_metric: 0.7262
# Epoch 109/500
# 21/21 [==============================] - 0s 16ms/step - loss: 236.9984 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 98ms/step - loss: 133.4496 - iou_metric: 0.8940 - val_loss: 236.9984 - val_iou_metric: 0.6548
# Epoch 110/500
# 21/21 [==============================] - 0s 16ms/step - loss: 229.0546 - iou_metric: 0.7500
#
# Epoch 00110: val_iou_metric did not improve from 0.75000
# 184/184 [==============================] - 18s 98ms/step - loss: 130.7540 - iou_metric: 0.9212 - val_loss: 229.0546 - val_iou_metric: 0.7500
# Epoch 111/500
# 21/21 [==============================] - 0s 16ms/step - loss: 247.7018 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 133.2848 - iou_metric: 0.9022 - val_loss: 247.7018 - val_iou_metric: 0.6548
# Epoch 112/500
# 21/21 [==============================] - 0s 16ms/step - loss: 229.4999 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 136.1277 - iou_metric: 0.8954 - val_loss: 229.4999 - val_iou_metric: 0.7262
# Epoch 113/500
# 21/21 [==============================] - 0s 16ms/step - loss: 238.4036 - iou_metric: 0.7738
# 184/184 [==============================] - 18s 97ms/step - loss: 133.2943 - iou_metric: 0.8995 - val_loss: 238.4036 - val_iou_metric: 0.7738
# Epoch 114/500
# 21/21 [==============================] - 0s 16ms/step - loss: 225.2291 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 98ms/step - loss: 126.5632 - iou_metric: 0.9253 - val_loss: 225.2291 - val_iou_metric: 0.7024
# Epoch 115/500
# 21/21 [==============================] - 0s 17ms/step - loss: 228.0310 - iou_metric: 0.6905
#
# Epoch 00115: val_iou_metric did not improve from 0.75000
# 184/184 [==============================] - 18s 97ms/step - loss: 125.2877 - iou_metric: 0.9307 - val_loss: 228.0310 - val_iou_metric: 0.6905
# Epoch 116/500
# 21/21 [==============================] - 0s 16ms/step - loss: 209.9638 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 98ms/step - loss: 124.2176 - iou_metric: 0.9117 - val_loss: 209.9638 - val_iou_metric: 0.7619
# Epoch 117/500
# 21/21 [==============================] - 0s 16ms/step - loss: 228.3838 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 130.9932 - iou_metric: 0.9035 - val_loss: 228.3838 - val_iou_metric: 0.7262
# Epoch 118/500
# 21/21 [==============================] - 0s 16ms/step - loss: 229.2589 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 98ms/step - loss: 131.8734 - iou_metric: 0.9130 - val_loss: 229.2589 - val_iou_metric: 0.7619
# Epoch 119/500
# 21/21 [==============================] - 0s 16ms/step - loss: 229.1470 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 128.7586 - iou_metric: 0.9049 - val_loss: 229.1470 - val_iou_metric: 0.6905
# Epoch 120/500
# 21/21 [==============================] - 0s 15ms/step - loss: 263.9198 - iou_metric: 0.6190
#
# Epoch 00120: val_iou_metric did not improve from 0.75000
# 184/184 [==============================] - 18s 98ms/step - loss: 129.6933 - iou_metric: 0.9022 - val_loss: 263.9198 - val_iou_metric: 0.6190
# Epoch 121/500
# 21/21 [==============================] - 0s 16ms/step - loss: 239.2816 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 97ms/step - loss: 129.0550 - iou_metric: 0.9035 - val_loss: 239.2816 - val_iou_metric: 0.7143
# Epoch 122/500
# 21/21 [==============================] - 0s 16ms/step - loss: 247.5718 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 98ms/step - loss: 128.3984 - iou_metric: 0.9062 - val_loss: 247.5718 - val_iou_metric: 0.6548
# Epoch 123/500
# 21/21 [==============================] - 0s 16ms/step - loss: 222.3367 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 125.5485 - iou_metric: 0.9103 - val_loss: 222.3367 - val_iou_metric: 0.7143
# Epoch 124/500
# 21/21 [==============================] - 0s 15ms/step - loss: 247.5579 - iou_metric: 0.7381
# 184/184 [==============================] - 18s 97ms/step - loss: 120.5951 - iou_metric: 0.9389 - val_loss: 247.5579 - val_iou_metric: 0.7381
# Epoch 125/500
# 21/21 [==============================] - 0s 16ms/step - loss: 211.4308 - iou_metric: 0.7619
#
# Epoch 00125: val_iou_metric improved from 0.75000 to 0.76190, saving model to model-0.76.h5
# 184/184 [==============================] - 19s 103ms/step - loss: 119.8259 - iou_metric: 0.9524 - val_loss: 211.4308 - val_iou_metric: 0.7619
# Epoch 126/500
# 21/21 [==============================] - 0s 15ms/step - loss: 252.0501 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 122.2758 - iou_metric: 0.9212 - val_loss: 252.0501 - val_iou_metric: 0.6548
# Epoch 127/500
# 21/21 [==============================] - 0s 16ms/step - loss: 211.2823 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 98ms/step - loss: 122.4457 - iou_metric: 0.9185 - val_loss: 211.2823 - val_iou_metric: 0.6786
# Epoch 128/500
# 21/21 [==============================] - 0s 15ms/step - loss: 211.5822 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 97ms/step - loss: 119.2854 - iou_metric: 0.9212 - val_loss: 211.5822 - val_iou_metric: 0.7500
# Epoch 129/500
# 21/21 [==============================] - 0s 15ms/step - loss: 250.3685 - iou_metric: 0.5952
# 184/184 [==============================] - 18s 98ms/step - loss: 125.4462 - iou_metric: 0.9062 - val_loss: 250.3685 - val_iou_metric: 0.5952
# Epoch 130/500
# 21/21 [==============================] - 0s 16ms/step - loss: 212.6200 - iou_metric: 0.7619
#
# Epoch 00130: val_iou_metric did not improve from 0.76190
# 184/184 [==============================] - 18s 97ms/step - loss: 121.7258 - iou_metric: 0.9226 - val_loss: 212.6200 - val_iou_metric: 0.7619
# Epoch 131/500
# 21/21 [==============================] - 0s 15ms/step - loss: 216.7225 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 97ms/step - loss: 122.6727 - iou_metric: 0.9035 - val_loss: 216.7225 - val_iou_metric: 0.6667
# Epoch 132/500
# 21/21 [==============================] - 0s 16ms/step - loss: 221.8431 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 123.0168 - iou_metric: 0.9212 - val_loss: 221.8431 - val_iou_metric: 0.7262
# Epoch 133/500
# 21/21 [==============================] - 0s 16ms/step - loss: 203.5465 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 127.1205 - iou_metric: 0.9062 - val_loss: 203.5465 - val_iou_metric: 0.7143
# Epoch 134/500
# 21/21 [==============================] - 0s 16ms/step - loss: 224.7543 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 97ms/step - loss: 111.9672 - iou_metric: 0.9389 - val_loss: 224.7543 - val_iou_metric: 0.7143
# Epoch 135/500
# 21/21 [==============================] - 0s 15ms/step - loss: 211.4721 - iou_metric: 0.7024
#
# Epoch 00135: val_iou_metric did not improve from 0.76190
# 184/184 [==============================] - 18s 97ms/step - loss: 117.4712 - iou_metric: 0.9239 - val_loss: 211.4721 - val_iou_metric: 0.7024
# Epoch 136/500
# 21/21 [==============================] - 0s 16ms/step - loss: 228.4066 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 122.3801 - iou_metric: 0.9062 - val_loss: 228.4066 - val_iou_metric: 0.7262
# Epoch 137/500
# 21/21 [==============================] - 0s 16ms/step - loss: 231.4783 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 120.1576 - iou_metric: 0.9117 - val_loss: 231.4783 - val_iou_metric: 0.7262
# Epoch 138/500
# 21/21 [==============================] - 0s 15ms/step - loss: 220.1516 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 117.1222 - iou_metric: 0.9185 - val_loss: 220.1516 - val_iou_metric: 0.7024
# Epoch 139/500
# 21/21 [==============================] - 0s 16ms/step - loss: 221.3603 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 116.3599 - iou_metric: 0.9226 - val_loss: 221.3603 - val_iou_metric: 0.7024
# Epoch 140/500
# 21/21 [==============================] - 0s 16ms/step - loss: 221.9770 - iou_metric: 0.7262
#
# Epoch 00140: val_iou_metric did not improve from 0.76190
# 184/184 [==============================] - 18s 97ms/step - loss: 114.7671 - iou_metric: 0.9253 - val_loss: 221.9770 - val_iou_metric: 0.7262
# Epoch 141/500
# 21/21 [==============================] - 0s 16ms/step - loss: 234.8169 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 113.6441 - iou_metric: 0.9402 - val_loss: 234.8169 - val_iou_metric: 0.7143
# Epoch 142/500
# 21/21 [==============================] - 0s 15ms/step - loss: 219.2024 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 113.6518 - iou_metric: 0.9307 - val_loss: 219.2024 - val_iou_metric: 0.7262
# Epoch 143/500
# 21/21 [==============================] - 0s 16ms/step - loss: 207.4149 - iou_metric: 0.7738
# 184/184 [==============================] - 18s 98ms/step - loss: 114.7812 - iou_metric: 0.9321 - val_loss: 207.4149 - val_iou_metric: 0.7738
# Epoch 144/500
# 21/21 [==============================] - 0s 15ms/step - loss: 206.5269 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 113.5171 - iou_metric: 0.9293 - val_loss: 206.5269 - val_iou_metric: 0.7262
# Epoch 145/500
# 21/21 [==============================] - 0s 15ms/step - loss: 189.7050 - iou_metric: 0.6905
#
# Epoch 00145: val_iou_metric did not improve from 0.76190
# 184/184 [==============================] - 18s 98ms/step - loss: 115.2876 - iou_metric: 0.9226 - val_loss: 189.7050 - val_iou_metric: 0.6905
# Epoch 146/500
# 21/21 [==============================] - 0s 16ms/step - loss: 191.8018 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 97ms/step - loss: 113.1176 - iou_metric: 0.9280 - val_loss: 191.8018 - val_iou_metric: 0.7143
# Epoch 147/500
# 21/21 [==============================] - 0s 16ms/step - loss: 217.4916 - iou_metric: 0.6786
# 184/184 [==============================] - 18s 97ms/step - loss: 111.3659 - iou_metric: 0.9185 - val_loss: 217.4916 - val_iou_metric: 0.6786
# Epoch 148/500
# 21/21 [==============================] - 0s 16ms/step - loss: 203.2838 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 111.7158 - iou_metric: 0.9361 - val_loss: 203.2838 - val_iou_metric: 0.6905
# Epoch 149/500
# 21/21 [==============================] - 0s 16ms/step - loss: 220.7269 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 97ms/step - loss: 112.3561 - iou_metric: 0.9239 - val_loss: 220.7269 - val_iou_metric: 0.7143
# Epoch 150/500
# 21/21 [==============================] - 0s 16ms/step - loss: 222.6179 - iou_metric: 0.7381
#
# Epoch 00150: val_iou_metric did not improve from 0.76190
# 184/184 [==============================] - 18s 98ms/step - loss: 111.6146 - iou_metric: 0.9130 - val_loss: 222.6179 - val_iou_metric: 0.7381
# Epoch 151/500
# 21/21 [==============================] - 0s 16ms/step - loss: 208.6996 - iou_metric: 0.7976
# 184/184 [==============================] - 18s 98ms/step - loss: 109.0390 - iou_metric: 0.9389 - val_loss: 208.6996 - val_iou_metric: 0.7976
# Epoch 152/500
# 21/21 [==============================] - 0s 16ms/step - loss: 214.5238 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 97ms/step - loss: 110.6438 - iou_metric: 0.9239 - val_loss: 214.5238 - val_iou_metric: 0.7262
# Epoch 153/500
# 21/21 [==============================] - 0s 15ms/step - loss: 210.5413 - iou_metric: 0.7381
# 184/184 [==============================] - 18s 97ms/step - loss: 113.5684 - iou_metric: 0.9171 - val_loss: 210.5413 - val_iou_metric: 0.7381
# Epoch 154/500
# 21/21 [==============================] - 0s 16ms/step - loss: 197.2881 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 110.8318 - iou_metric: 0.9321 - val_loss: 197.2881 - val_iou_metric: 0.7262
# Epoch 155/500
# 21/21 [==============================] - 0s 16ms/step - loss: 213.3425 - iou_metric: 0.7857
#
# Epoch 00155: val_iou_metric improved from 0.76190 to 0.78571, saving model to model-0.79.h5
# 184/184 [==============================] - 19s 103ms/step - loss: 106.9223 - iou_metric: 0.9416 - val_loss: 213.3425 - val_iou_metric: 0.7857
# Epoch 156/500
# 21/21 [==============================] - 0s 15ms/step - loss: 196.1543 - iou_metric: 0.7976
# 184/184 [==============================] - 18s 98ms/step - loss: 117.9859 - iou_metric: 0.8913 - val_loss: 196.1543 - val_iou_metric: 0.7976
# Epoch 157/500
# 21/21 [==============================] - 0s 16ms/step - loss: 212.3313 - iou_metric: 0.7262
# 184/184 [==============================] - 18s 98ms/step - loss: 113.1207 - iou_metric: 0.9171 - val_loss: 212.3313 - val_iou_metric: 0.7262
# Epoch 158/500
# 21/21 [==============================] - 0s 16ms/step - loss: 195.7703 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 111.2904 - iou_metric: 0.9239 - val_loss: 195.7703 - val_iou_metric: 0.7619
# Epoch 159/500
# 21/21 [==============================] - 0s 15ms/step - loss: 206.9371 - iou_metric: 0.7381
# 184/184 [==============================] - 18s 98ms/step - loss: 108.5095 - iou_metric: 0.9334 - val_loss: 206.9371 - val_iou_metric: 0.7381
# Epoch 160/500
# 21/21 [==============================] - 0s 15ms/step - loss: 188.2715 - iou_metric: 0.7857
#
# Epoch 00160: val_iou_metric did not improve from 0.78571
# 184/184 [==============================] - 18s 97ms/step - loss: 110.7084 - iou_metric: 0.9158 - val_loss: 188.2715 - val_iou_metric: 0.7857
# Epoch 161/500
# 21/21 [==============================] - 0s 16ms/step - loss: 171.9875 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 103.4929 - iou_metric: 0.9402 - val_loss: 171.9875 - val_iou_metric: 0.7619
# Epoch 162/500
# 21/21 [==============================] - 0s 16ms/step - loss: 202.2315 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 109.8676 - iou_metric: 0.9307 - val_loss: 202.2315 - val_iou_metric: 0.7024
# Epoch 163/500
# 21/21 [==============================] - 0s 16ms/step - loss: 194.2544 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 98ms/step - loss: 107.3937 - iou_metric: 0.9375 - val_loss: 194.2544 - val_iou_metric: 0.6667
# Epoch 164/500
# 21/21 [==============================] - 0s 16ms/step - loss: 199.7627 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 105.7900 - iou_metric: 0.9348 - val_loss: 199.7627 - val_iou_metric: 0.7619
# Epoch 165/500
# 21/21 [==============================] - 0s 16ms/step - loss: 197.1882 - iou_metric: 0.7381
#
# Epoch 00165: val_iou_metric did not improve from 0.78571
# 184/184 [==============================] - 18s 97ms/step - loss: 103.9447 - iou_metric: 0.9280 - val_loss: 197.1882 - val_iou_metric: 0.7381
# Epoch 166/500
# 21/21 [==============================] - 0s 16ms/step - loss: 202.4098 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 107.2086 - iou_metric: 0.9239 - val_loss: 202.4098 - val_iou_metric: 0.7024
# Epoch 167/500
# 21/21 [==============================] - 0s 16ms/step - loss: 212.3995 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 98ms/step - loss: 105.3042 - iou_metric: 0.9280 - val_loss: 212.3995 - val_iou_metric: 0.6905
# Epoch 168/500
# 21/21 [==============================] - 0s 16ms/step - loss: 200.5634 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 97ms/step - loss: 104.0496 - iou_metric: 0.9293 - val_loss: 200.5634 - val_iou_metric: 0.7500
# Epoch 169/500
# 21/21 [==============================] - 0s 16ms/step - loss: 201.5709 - iou_metric: 0.6310
# 184/184 [==============================] - 18s 97ms/step - loss: 102.3716 - iou_metric: 0.9334 - val_loss: 201.5709 - val_iou_metric: 0.6310
# Epoch 170/500
# 21/21 [==============================] - 0s 16ms/step - loss: 205.4846 - iou_metric: 0.7262
#
# Epoch 00170: val_iou_metric did not improve from 0.78571
# 184/184 [==============================] - 18s 97ms/step - loss: 106.3026 - iou_metric: 0.9293 - val_loss: 205.4846 - val_iou_metric: 0.7262
# Epoch 171/500
# 21/21 [==============================] - 0s 16ms/step - loss: 190.2255 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 103.7173 - iou_metric: 0.9226 - val_loss: 190.2255 - val_iou_metric: 0.7619
# Epoch 172/500
# 21/21 [==============================] - 0s 15ms/step - loss: 225.1869 - iou_metric: 0.6667
# 184/184 [==============================] - 18s 97ms/step - loss: 102.5703 - iou_metric: 0.9348 - val_loss: 225.1869 - val_iou_metric: 0.6667
# Epoch 173/500
# 21/21 [==============================] - 0s 15ms/step - loss: 206.4836 - iou_metric: 0.7381
# 184/184 [==============================] - 18s 98ms/step - loss: 101.8558 - iou_metric: 0.9361 - val_loss: 206.4836 - val_iou_metric: 0.7381
# Epoch 174/500
# 21/21 [==============================] - 0s 17ms/step - loss: 188.3904 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 98ms/step - loss: 104.1255 - iou_metric: 0.9334 - val_loss: 188.3904 - val_iou_metric: 0.7024
# Epoch 175/500
# 21/21 [==============================] - 0s 17ms/step - loss: 187.2330 - iou_metric: 0.7143
#
# Epoch 00175: val_iou_metric did not improve from 0.78571
# 184/184 [==============================] - 18s 100ms/step - loss: 105.9495 - iou_metric: 0.9253 - val_loss: 187.2330 - val_iou_metric: 0.7143
# Epoch 176/500
# 21/21 [==============================] - 0s 16ms/step - loss: 213.9105 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 99ms/step - loss: 102.7783 - iou_metric: 0.9185 - val_loss: 213.9105 - val_iou_metric: 0.7500
# Epoch 177/500
# 21/21 [==============================] - 0s 15ms/step - loss: 204.1698 - iou_metric: 0.7024
# 184/184 [==============================] - 18s 97ms/step - loss: 103.5180 - iou_metric: 0.9293 - val_loss: 204.1698 - val_iou_metric: 0.7024
# Epoch 178/500
# 21/21 [==============================] - 0s 15ms/step - loss: 183.8222 - iou_metric: 0.7857
# 184/184 [==============================] - 18s 97ms/step - loss: 100.5875 - iou_metric: 0.9429 - val_loss: 183.8222 - val_iou_metric: 0.7857
# Epoch 179/500
# 21/21 [==============================] - 0s 16ms/step - loss: 199.7670 - iou_metric: 0.7857
# 184/184 [==============================] - 18s 97ms/step - loss: 106.8276 - iou_metric: 0.9389 - val_loss: 199.7670 - val_iou_metric: 0.7857
# Epoch 180/500
# 21/21 [==============================] - 0s 15ms/step - loss: 211.9340 - iou_metric: 0.7619
#
# Epoch 00180: val_iou_metric did not improve from 0.78571
# 184/184 [==============================] - 18s 97ms/step - loss: 104.4244 - iou_metric: 0.9361 - val_loss: 211.9340 - val_iou_metric: 0.7619
# Epoch 181/500
# 21/21 [==============================] - 0s 16ms/step - loss: 188.9430 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 98ms/step - loss: 103.7572 - iou_metric: 0.9198 - val_loss: 188.9430 - val_iou_metric: 0.7500
# Epoch 182/500
# 21/21 [==============================] - 0s 15ms/step - loss: 178.8787 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 102.1674 - iou_metric: 0.9226 - val_loss: 178.8787 - val_iou_metric: 0.7619
# Epoch 183/500
# 21/21 [==============================] - 0s 16ms/step - loss: 206.5068 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 97ms/step - loss: 101.6210 - iou_metric: 0.9348 - val_loss: 206.5068 - val_iou_metric: 0.7500
# Epoch 184/500
# 21/21 [==============================] - 0s 16ms/step - loss: 194.4760 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 97ms/step - loss: 103.9269 - iou_metric: 0.9226 - val_loss: 194.4760 - val_iou_metric: 0.7500
# Epoch 185/500
# 21/21 [==============================] - 0s 16ms/step - loss: 201.5809 - iou_metric: 0.7143
#
# Epoch 00185: val_iou_metric did not improve from 0.78571
# 184/184 [==============================] - 18s 98ms/step - loss: 102.5105 - iou_metric: 0.9171 - val_loss: 201.5809 - val_iou_metric: 0.7143
# Epoch 186/500
# 21/21 [==============================] - 0s 15ms/step - loss: 184.5819 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 97ms/step - loss: 99.1283 - iou_metric: 0.9457 - val_loss: 184.5819 - val_iou_metric: 0.7500
# Epoch 187/500
# 21/21 [==============================] - 0s 15ms/step - loss: 186.2358 - iou_metric: 0.7619
# 184/184 [==============================] - 18s 97ms/step - loss: 98.6342 - iou_metric: 0.9361 - val_loss: 186.2358 - val_iou_metric: 0.7619
# Epoch 188/500
# 21/21 [==============================] - 0s 16ms/step - loss: 194.3868 - iou_metric: 0.7857
# 184/184 [==============================] - 18s 97ms/step - loss: 96.7789 - iou_metric: 0.9375 - val_loss: 194.3868 - val_iou_metric: 0.7857
# Epoch 189/500
# 21/21 [==============================] - 0s 16ms/step - loss: 191.4557 - iou_metric: 0.6548
# 184/184 [==============================] - 18s 97ms/step - loss: 96.1524 - iou_metric: 0.9416 - val_loss: 191.4557 - val_iou_metric: 0.6548
# Epoch 190/500
# 21/21 [==============================] - 0s 16ms/step - loss: 194.7120 - iou_metric: 0.7976
#
# Epoch 00190: val_iou_metric improved from 0.78571 to 0.79762, saving model to model-0.80.h5
# 184/184 [==============================] - 19s 104ms/step - loss: 96.9196 - iou_metric: 0.9280 - val_loss: 194.7120 - val_iou_metric: 0.7976
# Epoch 191/500
# 21/21 [==============================] - 0s 15ms/step - loss: 185.5965 - iou_metric: 0.7500
# 184/184 [==============================] - 18s 97ms/step - loss: 102.4994 - iou_metric: 0.9171 - val_loss: 185.5965 - val_iou_metric: 0.7500
# Epoch 192/500
# 21/21 [==============================] - 0s 16ms/step - loss: 186.2324 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 97ms/step - loss: 97.1411 - iou_metric: 0.9361 - val_loss: 186.2324 - val_iou_metric: 0.6905
# Epoch 193/500
# 21/21 [==============================] - 0s 15ms/step - loss: 180.7773 - iou_metric: 0.7857
# 184/184 [==============================] - 18s 99ms/step - loss: 93.2999 - iou_metric: 0.9538 - val_loss: 180.7773 - val_iou_metric: 0.7857
# Epoch 194/500
# 21/21 [==============================] - 0s 19ms/step - loss: 196.8043 - iou_metric: 0.6905
# 184/184 [==============================] - 18s 98ms/step - loss: 94.3648 - iou_metric: 0.9484 - val_loss: 196.8043 - val_iou_metric: 0.6905
# Epoch 195/500
# 21/21 [==============================] - 1s 33ms/step - loss: 188.4248 - iou_metric: 0.7500
#
# Epoch 00195: val_iou_metric did not improve from 0.79762
# 184/184 [==============================] - 19s 102ms/step - loss: 99.6830 - iou_metric: 0.9198 - val_loss: 188.4248 - val_iou_metric: 0.7500
# Epoch 196/500
# 21/21 [==============================] - 0s 15ms/step - loss: 188.8342 - iou_metric: 0.7738
# 184/184 [==============================] - 26s 142ms/step - loss: 95.1476 - iou_metric: 0.9280 - val_loss: 188.8342 - val_iou_metric: 0.7738
# Epoch 197/500
# 21/21 [==============================] - 0s 15ms/step - loss: 183.0005 - iou_metric: 0.7857
# 184/184 [==============================] - 18s 97ms/step - loss: 96.6532 - iou_metric: 0.9144 - val_loss: 183.0005 - val_iou_metric: 0.7857
# Epoch 198/500
# 21/21 [==============================] - 0s 17ms/step - loss: 192.5671 - iou_metric: 0.7143
# 184/184 [==============================] - 18s 98ms/step - loss: 97.4394 - iou_metric: 0.9253 - val_loss: 192.5671 - val_iou_metric: 0.7143
# Epoch 199/500
#  83/184 [============>.................] - ETA: 9s - loss: 95.8065 - iou_metric: 0.9428
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e46e9e17a2b8> in <module>()
#       9 # reduce_lr = ReduceLROnPlateau(monitor="iou_metric", factor=0.2, patience=10, min_lr=1e-7, verbose=1, mode="max")
#      10
# ---> 11 model.fit_generator(generator=train_datagen, validation_data=val_datagen, epochs=epochs, callbacks=[checkpoint], shuffle=True, verbose=1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424         use_multiprocessing=use_multiprocessing,
#    1425         shuffle=shuffle,
# -> 1426         initial_epoch=initial_epoch)
#    1427
#    1428   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, **kwargs)
#     189       progbar.on_batch_begin(step, batch_logs)
#     190
# --> 191       batch_outs = batch_function(*batch_data)
#     192       if not isinstance(batch_outs, list):
#     193         batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1189       else:
#    1190         self._make_fit_function()
# -> 1191         outputs = self._fit_function(ins)  # pylint: disable=not-callable
#    1192
#    1193     if reset_metrics:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# file = file_list[1]
# img = cv2.imread(file)
# mask = ip(img) # For ip - isn't appended yet
# img = np.stack([img[:,:,2], img[:,:,1], img[:,:,0]], axis=2)
# #   img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# #   tree = ET.parse(os.path.join(annot_dir, file.split('/')[-1])[:-3] + 'xml')
# tree = ET.parse(os.path.join('Labels', '/'.join(file.split('/')[-2:])[:-3] + 'xml'))
# root = tree.getroot()
# size = root.find('size')
# width = int(size.find('width').text)
# height = int(size.find('height').text)
# box = (root.find('object')).find('bndbox')
# xmin = int(box[0].text)
# ymin = int(box[1].text)
# xmax = int(box[2].text)
# ymax = int(box[3].text)
# print(([xmin, xmax, ymin, ymax]))
# img = cv2.rectangle(img,(xmin, ymin),(xmax, ymax), (0,255,0) ,3)
# plt.imshow(img)

# %%
file = drive.CreateFile({'title': 'BBmodel-0.80.h5'})
file.SetContentFile('model-0.80.h5')
file.Upload()

# %%
model.load_weights('model-0.80.h5')

# %%
batch_images, batch_coords = val_datagen.__getitem__(1)
i=0

# %%
pred = model.predict_on_batch(batch_images)

# %%
i=(i+1)%4
print(i)
print(pred[i])
img = batch_images[i][:,:,:-1].copy()+1
max_ = int(np.max(img))
img = cv2.rectangle(img,(batch_coords[i][0], batch_coords[i][2]),(batch_coords[i][1],batch_coords[i][3]),(max_, max_, max_),3)
# img = cv2.rectangle(img,(batch_coords[i][0], batch_coords[i][2]),(batch_coords[i][1],batch_coords[i][3]), (0,255,0) ,3)
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0
# [ 78.12192  137.43825  106.196686 166.93098 ]

# %%
# img_new, imgX1, imgX2, imgY1, imgY2 = scale(img, 224, 224, imgX1=xmin, imgX2=xmax, imgY1=ymin, imgY2=ymax)
# img_new = cv2.rectangle(img_new, (imgX1, imgY1),(imgX2, imgY2), (0,255,0) ,1)
# plt.imshow(img_new)

# %%
# def scale_pad(img, zoom_range=(0.8,1.2), imgX1=None, imgX2=None, imgY1=None, imgY2=None, interpolation=cv2.INTER_LINEAR):
    
#     '''Args: Image, new image width, new image height, 
#                  top left point x-coordinates, bottom right point x-coordinates,
#                  top left point y-coordinates, bottom right point y-coordinates, 
#                  interpolation    '''

#     imgTemp = img.copy()
#     imgHeight, imgWidth, _ = imgTemp.shape
#     zoom = random.uniform(zoom_range[0], zoom_range[1])
#     imgNewWidth = imgWidth*zoom
#     imgNewHeight = imgHeight*zoom
#     imgTemp = cv2.resize(imgTemp, (imgNewWidth, imgNewHeight), interpolation=interpolation)
#     diffWidth = (imgNewWidth - imgWidth)
#     diffHeight = (imgNewHeight - imgHeight)
#     width_off = int(diffWidth/2)
#     height_off = int(diffHeight/2)
#     if(width_off>0):
#       imgTemp = imgTemp[height_off:height_off+imgHeight, width_off:width_off+imgWidth]
#     else:
#       imgTemp = cv2.copyMakeBorder(imgTemp, int(height_off/2), imgHeight-imgNewHeight-int(height_off/2), int(width_off/2), 
#                                    imgWidth-imgNewWidth-int(width_off/2), BORDER_REPLICATE )

#     if imgX1!=None:
#         fY = float(imgNewHeight)/float(imgHeight)
#         fX = float(imgNewWidth)/float(imgWidth)

#         imgX1 = max(0, int(imgX1*fX))
#         imgX2 = min(int(imgX2*fX), imgNewWidth)
#         imgY1 = max(0, int(imgY1*fY))
#         imgY2 = min(int(imgY2*fY), imgNewHeight)
        
#         imgX1 -= width_off
#         imgX2 -= width_off
#         imgY1 -= height_off
#         imgY2 -= heght_off

#         return imgTemp, imgX1, imgX2, imgY1, imgY2
#     else:
#         return imgTemp

# %%
# class repeat_channel(image_gen):
#   def __init__(self, image_gen):
#     super(repeat_channel, self).__init__()
#     self.gen = image_gen
    
#   def __len__(self):
#     return 141
  
#   def __getitem__(self, idx):
#     img, y = self.gen.next()
#     return (np.concatenate([img,img,img], axis=3), y)

# %%
# from google.colab import files
# uploaded = files.upload()
# for k, v in uploaded.items():
#   open(k, 'wb').write(v)
# list(uploaded.keys())

# %%
# batch_images, batch_coords = train_datagen.__getitem__(0)
# i=0

# %%
# i=(i+1)%4
# print(i)
# print(batch_coords[i])
# img = batch_images[i].copy()+1
# max_ = int(np.max(img))
# img = cv2.rectangle(img,(batch_coords[i][0], batch_coords[i][2]),(batch_coords[i][1],batch_coords[i][3]),(max_, max_, max_),3)
# # img = cv2.rectangle(img,(batch_coords[i][0], batch_coords[i][2]),(batch_coords[i][1],batch_coords[i][3]), (0,255,0) ,3)
# plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0
# [ 73 146  69 106]

# %%
# datagen = ImageDataGenerator(width_shift_range=0.2, height_shift_range=0.2, brightness_range=(0.7,1.3), zoom_range=0.4, 
#                    fill_mode='reflect', horizontal_flip=True, vertical_flip=True, rescale=1/255, validation_split=0.1)
